# %% [markdown]
# # PayNet assesment
#
# #### Prepared by Ainur Afifah

# %% [markdown]
# todo:
# 1. Merge structure (from nested into single)
# 2. Separate person name into first and last
# 3. Convert timestamps into UTC +8
# 4. Create charts & visualization
# 5. PII approach with reasons

# %% [markdown]
# ## Read JSON data

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("cc-data-cleaning-visualization").getOrCreate()
json_file_path = "/Users/ainurafifah/Desktop/PROJECTS/portfolio/PayNet/cc_sample_transaction.json"


try:
    df = spark.read.option("multiline", "true").json(json_file_path)
    df = spark.read.json(json_file_path)
    
    print("Full schema:")
    df.printSchema()
    
    df.show(5, truncate=False, vertical=True)
    
    
except Exception as e:
    print(f"Error reading JSON file: {e}")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/22 14:40:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Full schema:
# root
#  |-- Unnamed: 0: string (nullable = true)
#  |-- amt: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- cc_bic: string (nullable = true)
#  |-- cc_num: string (nullable = true)
#  |-- is_fraud: string (nullable = true)
#  |-- merch_eff_time: string (nullable = true)
#  |-- merch_last_update_time: string (nullable = true)
#  |-- merch_lat: string (nullable = true)
#  |-- merch_long: string (nullable = true)
#  |-- merch_zipcode: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- personal_detail: string (nullable = true)
#  |-- trans_date_trans_time: string (nullable = true)
#  |-- trans_num: string (nullable = true)
#
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Unnamed: 0             | 0
#  amt                    | 4.97
#  category               | misc_net
#  cc_bic                 | CITIUS33CHI
#  cc_num                 | 2703186189652095
#  is_fraud               | 0
#  merch_eff_time         | 1325376018798532
#  merch_last_update_time | 1325376018666
#  merch_lat              | 36.011293
#  merch_long             | -82.048315
#  merch_zipcode          | 28705
#  merchant               | fraud_Rippin, Kub and Mann
#  personal_detail        | {"person_name":"Jennifer,Banks,eeeee","gender":"F","address":"{\"street\":\"561 Perry Cove\",\"city\":\"Moravian Falls\",\"state\":\"NC\",\"zip\":\"28654\"}","lat":"36.0788","long":"-81.1781","city_pop":"3495","job":"Psychologist, counselling","dob":"1988-03-09"}
#  trans_date_trans_time  | 2019-01-01 00:00:18
#  trans_num              | 0b242abb623afc578575680df30655b9
# -RECORD 1-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Unnamed: 0             | 1
#  amt                    | 107.23
#  category               | grocery_pos
#  cc_bic                 | ADMDUS41
#  cc_num                 | 630423337322
#  is_fraud               | 0
#  merch_eff_time         | 1325376044867960
#  merch_last_update_time | 132537604479
#  merch_lat              | 49.159046999999994
#  merch_long             | -118.186462
#  merch_zipcode          | NULL
#  merchant               | fraud_Heller, Gutmann and Zieme
#  personal_detail        | {"person_name":"Stephanie,Gill,eeeee","gender":"F","address":"{\"street\":\"43039 Riley Greens Suite 393\",\"city\":\"Orient\",\"state\":\"WA\",\"zip\":\"99160\"}","lat":"48.8878","long":"-118.2105","city_pop":"149","job":"Special educational needs teacher","dob":"1978-06-21"}
#  trans_date_trans_time  | 2019-01-01 00:00:44
#  trans_num              | 1f76529f8574734946361c461b024d99
# -RECORD 2-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Unnamed: 0             | 2
#  amt                    | 220.11
#  category               | entertainment
#  cc_bic                 | Null
#  cc_num                 | 38859492057661
#  is_fraud               | 0
#  merch_eff_time         | 1325376051506840
#  merch_last_update_time | 1325376051286
#  merch_lat              | 43.150704
#  merch_long             | -112.154481
#  merch_zipcode          | 83236
#  merchant               | fraud_Lind-Buckridge
#  personal_detail        | {"person_name":"Edward@Sanchez","gender":"M","address":"{\"street\":\"594 White Dale Suite 530\",\"city\":\"Malad City\",\"state\":\"ID\",\"zip\":\"83252\"}","lat":"42.1808","long":"-112.262","city_pop":"4154","job":"Nature conservation officer","dob":"1962-01-19"}
#  trans_date_trans_time  | 2019-01-01 00:00:51
#  trans_num              | a1a22d70485983eac12b5b88dad1cf95
# -RECORD 3-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Unnamed: 0             | 3
#  amt                    | 45.0
#  category               | gas_transport
#  cc_bic                 | DEUTUS33TRF
#  cc_num                 | 3534093764340240
#  is_fraud               | 0
#  merch_eff_time         | 1325376076794698
#  merch_last_update_time | 1325376076365
#  merch_lat              | 47.034331
#  merch_long             | -112.561071
#  merch_zipcode          | NULL
#  merchant               | fraud_Kutch, Hermiston and Farrell
#  personal_detail        | {"person_name":"Jeremy/White, !","gender":"M","address":"{\"street\":\"9443 Cynthia Court Apt. 038\",\"city\":\"Boulder\",\"state\":\"MT\",\"zip\":\"59632\"}","lat":"46.2306","long":"-112.1138","city_pop":"1939","job":"Patent attorney","dob":"1967-01-12"}
#  trans_date_trans_time  | 2019-01-01 00:01:16
#  trans_num              | 6b849c168bdad6f867558c3793159a81
# -RECORD 4-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Unnamed: 0             | 4
#  amt                    | 41.96
#  category               | misc_pos
#  cc_bic                 | APBCUS61
#  cc_num                 | 375534208663984
#  is_fraud               | 0
#  merch_eff_time         | 1325376186746376
#  merch_last_update_time | 132537618681
#  merch_lat              | 38.674999
#  merch_long             | -78.632459
#  merch_zipcode          | 22844
#  merchant               | fraud_Keeling-Crist
#  personal_detail        | {"person_name":"Tyler@Garcia","gender":"M","address":"{\"street\":\"408 Bradley Rest\",\"city\":\"Doe Hill\",\"state\":\"VA\",\"zip\":\"24433\"}","lat":"38.4207","long":"-79.4629","city_pop":"99","job":"Dance movement psychotherapist","dob":"1986-03-28"}
#  trans_date_trans_time  | 2019-01-01 00:03:06
#  trans_num              | a41d7549acf90789359a9aa5346dcb46
# only showing top 5 rows

# %% [markdown]
# ## Required changes

# %% [markdown]
# ### 1. Convert timestamp format

# %%
from pyspark.sql.functions import date_format, from_unixtime, to_timestamp, from_utc_timestamp, col

# Convert timestamp to UTC+8
# Set timezone configuration
spark.conf.set("spark.sql.session.timeZone", "UTC+8")
    
df = df.withColumn("trans_date_trans_time_utc8",to_timestamp(col("trans_date_trans_time")))
    
df = df.withColumn("merch_eff_time_utc8",from_unixtime(col("merch_eff_time") / 1000000))

df = df.withColumn("merch_last_update_time_utc8",from_unixtime(col("merch_last_update_time") / 1000))

# %%
#Updated schema (3 new timestamp utc8 columns are added)
df.printSchema()
# Out:
# root
#  |-- Unnamed: 0: string (nullable = true)
#  |-- amt: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- cc_bic: string (nullable = true)
#  |-- cc_num: string (nullable = true)
#  |-- is_fraud: string (nullable = true)
#  |-- merch_eff_time: string (nullable = true)
#  |-- merch_last_update_time: string (nullable = true)
#  |-- merch_lat: string (nullable = true)
#  |-- merch_long: string (nullable = true)
#  |-- merch_zipcode: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- personal_detail: string (nullable = true)
#  |-- trans_date_trans_time: string (nullable = true)
#  |-- trans_num: string (nullable = true)
#  |-- trans_date_trans_time_utc8: timestamp (nullable = true)
#  |-- merch_eff_time_utc8: string (nullable = true)
#  |-- merch_last_update_time_utc8: string (nullable = true)

# %% [markdown]
# ### 2. Flatten the JSON
#
# These 2 columns will appear in the root schema
# 1. personal_detail
# 2. address

# %%
from pyspark.sql.types import StringType, StructType, StructField
from pyspark.sql.functions import col, from_json, split, concat, lit, substring, regexp_extract, abs
from pyspark.sql.functions import regexp_replace, when, array_contains, size, get_json_object
from pyspark.sql.functions import to_date, year, month, dayofmonth


# Define schema for nested structures
address_schema = StructType([
                        StructField("street", StringType()),
                        StructField("city", StringType()),
                        StructField("state", StringType()),
                        StructField("zip", StringType())
                        ])

personal_detail_schema = StructType([
                        StructField("person_name", StringType()),
                        StructField("gender", StringType()),
                        StructField("address", StringType()),
                        StructField("lat", StringType()),
                        StructField("long", StringType()),
                        StructField("city_pop", StringType()),
                        StructField("job", StringType()),   
                        StructField("dob", StringType())
                        ])


# Parse nested JSON strings
df_parsed = df.withColumn("personal_detail_parsed", from_json("personal_detail", personal_detail_schema))

# %%
df_parsed.printSchema()
# Out:
# root
#  |-- Unnamed: 0: string (nullable = true)
#  |-- amt: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- cc_bic: string (nullable = true)
#  |-- cc_num: string (nullable = true)
#  |-- is_fraud: string (nullable = true)
#  |-- merch_eff_time: string (nullable = true)
#  |-- merch_last_update_time: string (nullable = true)
#  |-- merch_lat: string (nullable = true)
#  |-- merch_long: string (nullable = true)
#  |-- merch_zipcode: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- personal_detail: string (nullable = true)
#  |-- trans_date_trans_time: string (nullable = true)
#  |-- trans_num: string (nullable = true)
#  |-- trans_date_trans_time_utc8: timestamp (nullable = true)
#  |-- merch_eff_time_utc8: string (nullable = true)
#  |-- merch_last_update_time_utc8: string (nullable = true)
#  |-- personal_detail_parsed: struct (nullable = true)
#  |    |-- person_name: string (nullable = true)
#  |    |-- gender: string (nullable = true)
#  |    |-- address: string (nullable = true)
#  |    |-- lat: string (nullable = true)
#  |    |-- long: string (nullable = true)
#  |    |-- city_pop: string (nullable = true)
#  |    |-- job: string (nullable = true)
#  |    |-- dob: string (nullable = true)

# %%
df_final = df_parsed.withColumn("address_parsed",from_json(
                regexp_replace(col("personal_detail_parsed.address"), r'\\"', '"'),
                address_schema))

# %%
df_final.printSchema()
# Out:
# root
#  |-- Unnamed: 0: string (nullable = true)
#  |-- amt: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- cc_bic: string (nullable = true)
#  |-- cc_num: string (nullable = true)
#  |-- is_fraud: string (nullable = true)
#  |-- merch_eff_time: string (nullable = true)
#  |-- merch_last_update_time: string (nullable = true)
#  |-- merch_lat: string (nullable = true)
#  |-- merch_long: string (nullable = true)
#  |-- merch_zipcode: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- personal_detail: string (nullable = true)
#  |-- trans_date_trans_time: string (nullable = true)
#  |-- trans_num: string (nullable = true)
#  |-- trans_date_trans_time_utc8: timestamp (nullable = true)
#  |-- merch_eff_time_utc8: string (nullable = true)
#  |-- merch_last_update_time_utc8: string (nullable = true)
#  |-- personal_detail_parsed: struct (nullable = true)
#  |    |-- person_name: string (nullable = true)
#  |    |-- gender: string (nullable = true)
#  |    |-- address: string (nullable = true)
#  |    |-- lat: string (nullable = true)
#  |    |-- long: string (nullable = true)
#  |    |-- city_pop: string (nullable = true)
#  |    |-- job: string (nullable = true)
#  |    |-- dob: string (nullable = true)
#  |-- address_parsed: struct (nullable = true)
#  |    |-- street: string (nullable = true)
#  |    |-- city: string (nullable = true)
#  |    |-- state: string (nullable = true)
#  |    |-- zip: string (nullable = true)

# %% [markdown]
# ### 3. Split the person_name into first & last
# 1. The name has different type of delimiters
# 2. First name is 'first' and the second name is 'last'
#
# ### 4. Create a new column 'year' from 'dob'
# 1. To assess if there is a pattern in age group & fraud cases
#
# ### 5. Create new columns from 'merchant'
# 1. There is an existing is_fraud column. Will require to do a distribution analysis for this column.
# 2. Bcs merchant column has a 'fraud_' marker in the name. Assumption is the merchant is a fraud case.
# 3. Will create 2 columns: fraud_flag & merchant_name.
# 4. Original merchant column is still part of the dataframe until further investigation.

# %%
import re
# Handling person_name column split
DELIMITERS = [",", "@", "/", "!", "\\\\"]
delimiter_pattern = "|".join([re.escape(d) for d in DELIMITERS])
    
df_final = df_final.withColumn("normalized_name",
        regexp_replace(col("personal_detail_parsed.person_name"), 
                       delimiter_pattern, "|")).withColumn("name_parts",
                                                           split(col("normalized_name"), "\\|"))
    
spark.conf.set("spark.sql.debug.maxToStringFields", "1000")

# %%
from pyspark.sql.functions import col, from_json, split, concat, lit, substring, regexp_extract, abs

df_final = df_final.withColumn("fraud_flag",
       regexp_extract(col("merchant"), "^fraud_", 0))

df_final = df_final.withColumn("merchant_name",
       regexp_extract(col("merchant"), "[^_]+$", 0))

#create a Boolean column from fraud_flag 
df_final = df_final.withColumn("derived_fraud_flag",
    when(col("merchant").startswith("fraud_"), True).otherwise(False))

#cast is_fraud column into Boolean type
df_final = df_final.withColumn("is_fraud_bool",
       col("is_fraud").cast("boolean"))

# %%
df_final = df_final.withColumn("amount_clean",
       abs(col("amt").cast("decimal(10,2)"))).filter(col("amount_clean") < 100000)

# %%
flattened_df = df_final.select(
            "Unnamed: 0",
            "amt",
            "amount_clean",
            "category",
            "cc_bic",
            "cc_num",
            "merch_eff_time",
            "merch_last_update_time",
            "merch_lat",
            "merch_long",
            "merch_zipcode",
            "merchant",
            "merchant_name",
            "fraud_flag",
            "derived_fraud_flag",
            "is_fraud_bool",
            "is_fraud",
            "trans_date_trans_time",
            "trans_num",
            "trans_date_trans_time_utc8",
            "merch_eff_time_utc8",
            "merch_last_update_time_utc8",
            col("personal_detail_parsed.person_name").alias("person_name"),
            
            when((size(col("name_parts")) > 0) & (col("name_parts")[0] != ""), 
            col("name_parts")[0]).otherwise(lit(None)).alias("first"),
        
            when((size(col("name_parts")) > 1) & (col("name_parts")[1] != ""),
            col("name_parts")[1]).otherwise(lit(None)).alias("last"),
    
            col("personal_detail_parsed.gender").alias("gender"),
            col("address_parsed.street").alias("street"),
            col("address_parsed.city").alias("city"),
            col("address_parsed.state").alias("state"),
            col("address_parsed.zip").alias("zip"),
            col("personal_detail_parsed.lat").alias("lat"),
            col("personal_detail_parsed.long").alias("long"),
            col("personal_detail_parsed.city_pop").alias("city_pop"),
            col("personal_detail_parsed.job").alias("job"),
            year(to_date(col("personal_detail_parsed.dob"))).alias("birth_year"),
            col("personal_detail_parsed.dob").alias("dob")   
        )

flattened_df.printSchema()
# Out:
# root
#  |-- Unnamed: 0: string (nullable = true)
#  |-- amt: string (nullable = true)
#  |-- amount_clean: decimal(10,2) (nullable = true)
#  |-- category: string (nullable = true)
#  |-- cc_bic: string (nullable = true)
#  |-- cc_num: string (nullable = true)
#  |-- merch_eff_time: string (nullable = true)
#  |-- merch_last_update_time: string (nullable = true)
#  |-- merch_lat: string (nullable = true)
#  |-- merch_long: string (nullable = true)
#  |-- merch_zipcode: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- merchant_name: string (nullable = true)
#  |-- fraud_flag: string (nullable = true)
#  |-- derived_fraud_flag: boolean (nullable = false)
#  |-- is_fraud_bool: boolean (nullable = true)
#  |-- is_fraud: string (nullable = true)
#  |-- trans_date_trans_time: string (nullable = true)
#  |-- trans_num: string (nullable = true)
#  |-- trans_date_trans_time_utc8: timestamp (nullable = true)
#  |-- merch_eff_time_utc8: string (nullable = true)
#  |-- merch_last_update_time_utc8: string (nullable = true)
#  |-- person_name: string (nullable = true)
#  |-- first: string (nullable = true)
#  |-- last: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- street: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- zip: string (nullable = true)
#  |-- lat: string (nullable = true)
#  |-- long: string (nullable = true)
#  |-- city_pop: string (nullable = true)
#  |-- job: string (nullable = true)
#  |-- birth_year: integer (nullable = true)
#  |-- dob: string (nullable = true)

# %% [markdown]
# ### Summary

# %%
flattened_df.show(vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  Unnamed: 0                  | 0
#  amt                         | 4.97
#  amount_clean                | 4.97
#  category                    | misc_net
#  cc_bic                      | CITIUS33CHI
#  cc_num                      | 2703186189652095
#  merch_eff_time              | 1325376018798532
#  merch_last_update_time      | 1325376018666
#  merch_lat                   | 36.011293
#  merch_long                  | -82.048315
#  merch_zipcode               | 28705
#  merchant                    | fraud_Rippin, Kub...
#  merchant_name               | Rippin, Kub and Mann
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:00:18
#  trans_num                   | 0b242abb623afc578...
#  trans_date_trans_time_utc8  | 2019-01-01 00:00:18
#  merch_eff_time_utc8         | 2012-01-01 08:00:18
#  merch_last_update_time_utc8 | 2012-01-01 08:00:18
#  person_name                 | Jennifer,Banks,eeeee
#  first                       | Jennifer
#  last                        | Banks
#  gender                      | F
#  street                      | 561 Perry Cove
#  city                        | Moravian Falls
#  state                       | NC
#  zip                         | 28654
#  lat                         | 36.0788
#  long                        | -81.1781
#  city_pop                    | 3495
#  job                         | Psychologist, cou...
#  birth_year                  | 1988
#  dob                         | 1988-03-09
# -RECORD 1-------------------------------------------
#  Unnamed: 0                  | 1
#  amt                         | 107.23
#  amount_clean                | 107.23
#  category                    | grocery_pos
#  cc_bic                      | ADMDUS41
#  cc_num                      | 630423337322
#  merch_eff_time              | 1325376044867960
#  merch_last_update_time      | 132537604479
#  merch_lat                   | 49.159046999999994
#  merch_long                  | -118.186462
#  merch_zipcode               | NULL
#  merchant                    | fraud_Heller, Gut...
#  merchant_name               | Heller, Gutmann a...
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:00:44
#  trans_num                   | 1f76529f857473494...
#  trans_date_trans_time_utc8  | 2019-01-01 00:00:44
#  merch_eff_time_utc8         | 2012-01-01 08:00:44
#  merch_last_update_time_utc8 | 1974-03-15 08:00:04
#  person_name                 | Stephanie,Gill,eeeee
#  first                       | Stephanie
#  last                        | Gill
#  gender                      | F
#  street                      | 43039 Riley Green...
#  city                        | Orient
#  state                       | WA
#  zip                         | 99160
#  lat                         | 48.8878
#  long                        | -118.2105
#  city_pop                    | 149
#  job                         | Special education...
#  birth_year                  | 1978
#  dob                         | 1978-06-21
# -RECORD 2-------------------------------------------
#  Unnamed: 0                  | 2
#  amt                         | 220.11
#  amount_clean                | 220.11
#  category                    | entertainment
#  cc_bic                      | Null
#  cc_num                      | 38859492057661
#  merch_eff_time              | 1325376051506840
#  merch_last_update_time      | 1325376051286
#  merch_lat                   | 43.150704
#  merch_long                  | -112.154481
#  merch_zipcode               | 83236
#  merchant                    | fraud_Lind-Buckridge
#  merchant_name               | Lind-Buckridge
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:00:51
#  trans_num                   | a1a22d70485983eac...
#  trans_date_trans_time_utc8  | 2019-01-01 00:00:51
#  merch_eff_time_utc8         | 2012-01-01 08:00:51
#  merch_last_update_time_utc8 | 2012-01-01 08:00:51
#  person_name                 | Edward@Sanchez
#  first                       | Edward
#  last                        | Sanchez
#  gender                      | M
#  street                      | 594 White Dale Su...
#  city                        | Malad City
#  state                       | ID
#  zip                         | 83252
#  lat                         | 42.1808
#  long                        | -112.262
#  city_pop                    | 4154
#  job                         | Nature conservati...
#  birth_year                  | 1962
#  dob                         | 1962-01-19
# -RECORD 3-------------------------------------------
#  Unnamed: 0                  | 3
#  amt                         | 45.0
#  amount_clean                | 45.00
#  category                    | gas_transport
#  cc_bic                      | DEUTUS33TRF
#  cc_num                      | 3534093764340240
#  merch_eff_time              | 1325376076794698
#  merch_last_update_time      | 1325376076365
#  merch_lat                   | 47.034331
#  merch_long                  | -112.561071
#  merch_zipcode               | NULL
#  merchant                    | fraud_Kutch, Herm...
#  merchant_name               | Kutch, Hermiston ...
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:01:16
#  trans_num                   | 6b849c168bdad6f86...
#  trans_date_trans_time_utc8  | 2019-01-01 00:01:16
#  merch_eff_time_utc8         | 2012-01-01 08:01:16
#  merch_last_update_time_utc8 | 2012-01-01 08:01:16
#  person_name                 | Jeremy/White, !
#  first                       | Jeremy
#  last                        | White
#  gender                      | M
#  street                      | 9443 Cynthia Cour...
#  city                        | Boulder
#  state                       | MT
#  zip                         | 59632
#  lat                         | 46.2306
#  long                        | -112.1138
#  city_pop                    | 1939
#  job                         | Patent attorney
#  birth_year                  | 1967
#  dob                         | 1967-01-12
# -RECORD 4-------------------------------------------
#  Unnamed: 0                  | 4
#  amt                         | 41.96
#  amount_clean                | 41.96
#  category                    | misc_pos
#  cc_bic                      | APBCUS61
#  cc_num                      | 375534208663984
#  merch_eff_time              | 1325376186746376
#  merch_last_update_time      | 132537618681
#  merch_lat                   | 38.674999
#  merch_long                  | -78.632459
#  merch_zipcode               | 22844
#  merchant                    | fraud_Keeling-Crist
#  merchant_name               | Keeling-Crist
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:03:06
#  trans_num                   | a41d7549acf907893...
#  trans_date_trans_time_utc8  | 2019-01-01 00:03:06
#  merch_eff_time_utc8         | 2012-01-01 08:03:06
#  merch_last_update_time_utc8 | 1974-03-15 08:00:18
#  person_name                 | Tyler@Garcia
#  first                       | Tyler
#  last                        | Garcia
#  gender                      | M
#  street                      | 408 Bradley Rest
#  city                        | Doe Hill
#  state                       | VA
#  zip                         | 24433
#  lat                         | 38.4207
#  long                        | -79.4629
#  city_pop                    | 99
#  job                         | Dance movement ps...
#  birth_year                  | 1986
#  dob                         | 1986-03-28
# -RECORD 5-------------------------------------------
#  Unnamed: 0                  | 5
#  amt                         | 94.63
#  amount_clean                | 94.63
#  category                    | gas_transport
#  cc_bic                      | APBCUS61
#  cc_num                      | 4767265376804500
#  merch_eff_time              | 1325376248271406
#  merch_last_update_time      | 1325376248483
#  merch_lat                   | 40.653382
#  merch_long                  | -76.15266700000001
#  merch_zipcode               | 17972
#  merchant                    | fraud_Stroman, Hu...
#  merchant_name               | Stroman, Hudson a...
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:04:08
#  trans_num                   | 189a841a0a8ba0305...
#  trans_date_trans_time_utc8  | 2019-01-01 00:04:08
#  merch_eff_time_utc8         | 2012-01-01 08:04:08
#  merch_last_update_time_utc8 | 2012-01-01 08:04:08
#  person_name                 | Jennifer,Conner,e...
#  first                       | Jennifer
#  last                        | Conner
#  gender                      | F
#  street                      | 4655 David Island
#  city                        | Dublin
#  state                       | PA
#  zip                         | 18917
#  lat                         | 40.375
#  long                        | -75.2045
#  city_pop                    | 2158
#  job                         | Transport planner
#  birth_year                  | 1961
#  dob                         | 1961-06-19
# -RECORD 6-------------------------------------------
#  Unnamed: 0                  | 6
#  amt                         | 44.54
#  amount_clean                | 44.54
#  category                    | grocery_net
#  cc_bic                      | APBCUS61
#  cc_num                      | 30074693890476
#  merch_eff_time              | 1325376282274130
#  merch_last_update_time      | 1325376282247
#  merch_lat                   | 37.162704999999995
#  merch_long                  | -100.15337
#  merch_zipcode               | NULL
#  merchant                    | fraud_Rowe-Vander...
#  merchant_name               | Rowe-Vandervort
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:04:42
#  trans_num                   | 83ec1cc84142af6e2...
#  trans_date_trans_time_utc8  | 2019-01-01 00:04:42
#  merch_eff_time_utc8         | 2012-01-01 08:04:42
#  merch_last_update_time_utc8 | 2012-01-01 08:04:42
#  person_name                 | Kelsey, , Richard...
#  first                       | Kelsey
#  last                        |
#  gender                      | F
#  street                      | 889 Sarah Station...
#  city                        | Holcomb
#  state                       | KS
#  zip                         | 67851
#  lat                         | 37.9931
#  long                        | -100.9893
#  city_pop                    | 2691
#  job                         | Arboriculturist
#  birth_year                  | 1993
#  dob                         | 1993-08-16
# -RECORD 7-------------------------------------------
#  Unnamed: 0                  | 7
#  amt                         | 71.65
#  amount_clean                | 71.65
#  category                    | gas_transport
#  cc_bic                      | NA
#  cc_num                      | 6011360759745864
#  merch_eff_time              | 1325376308837349
#  merch_last_update_time      | 1325376308152
#  merch_lat                   | 38.948089
#  merch_long                  | -78.540296
#  merch_zipcode               | 22644
#  merchant                    | fraud_Corwin-Collins
#  merchant_name               | Corwin-Collins
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:05:08
#  trans_num                   | 6d294ed2cc447d2c7...
#  trans_date_trans_time_utc8  | 2019-01-01 00:05:08
#  merch_eff_time_utc8         | 2012-01-01 08:05:08
#  merch_last_update_time_utc8 | 2012-01-01 08:05:08
#  person_name                 | Steven, Williams
#  first                       | Steven
#  last                        |  Williams
#  gender                      | M
#  street                      | 231 Flores Pass S...
#  city                        | Edinburg
#  state                       | VA
#  zip                         | 22824
#  lat                         | 38.8432
#  long                        | -78.6003
#  city_pop                    | 6018
#  job                         | Designer, multimedia
#  birth_year                  | 1947
#  dob                         | 1947-08-21
# -RECORD 8-------------------------------------------
#  Unnamed: 0                  | 8
#  amt                         | 4.27
#  amount_clean                | 4.27
#  category                    | misc_pos
#  cc_bic                      | ACEEUS31
#  cc_num                      | 4922710831011201
#  merch_eff_time              | 1325376318245892
#  merch_last_update_time      | 1325376318278
#  merch_lat                   | 40.351813
#  merch_long                  | -79.958146
#  merch_zipcode               | 15236
#  merchant                    | fraud_Herzog Ltd
#  merchant_name               | Herzog Ltd
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:05:18
#  trans_num                   | fc28024ce480f8ef2...
#  trans_date_trans_time_utc8  | 2019-01-01 00:05:18
#  merch_eff_time_utc8         | 2012-01-01 08:05:18
#  merch_last_update_time_utc8 | 2012-01-01 08:05:18
#  person_name                 | Heather, , Chase ...
#  first                       | Heather
#  last                        |
#  gender                      | F
#  street                      | 6888 Hicks Stream...
#  city                        | Manor
#  state                       | PA
#  zip                         | 15665
#  lat                         | 40.3359
#  long                        | -79.6607
#  city_pop                    | 1472
#  job                         | Public affairs co...
#  birth_year                  | 1941
#  dob                         | 1941-03-07
# -RECORD 9-------------------------------------------
#  Unnamed: 0                  | 9
#  amt                         | 198.39
#  amount_clean                | 198.39
#  category                    | grocery_pos
#  cc_bic                      | DEUTUS33TRF
#  cc_num                      | 2720830304681674
#  merch_eff_time              | 1325376361965234
#  merch_last_update_time      | 1325376361857
#  merch_lat                   | 37.179198
#  merch_long                  | -87.485381
#  merch_zipcode               | 42442
#  merchant                    | fraud_Schoen, Kup...
#  merchant_name               | Schoen, Kuphal an...
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:06:01
#  trans_num                   | 3b9014ea8fb80bd65...
#  trans_date_trans_time_utc8  | 2019-01-01 00:06:01
#  merch_eff_time_utc8         | 2012-01-01 08:06:01
#  merch_last_update_time_utc8 | 2012-01-01 08:06:01
#  person_name                 | Melissa@Aguilar
#  first                       | Melissa
#  last                        | Aguilar
#  gender                      | F
#  street                      | 21326 Taylor Squa...
#  city                        | Clarksville
#  state                       | TN
#  zip                         | 37040
#  lat                         | 36.522
#  long                        | -87.34899999999999
#  city_pop                    | 151785
#  job                         | Pathologist
#  birth_year                  | 1974
#  dob                         | 1974-03-28
# -RECORD 10------------------------------------------
#  Unnamed: 0                  | 10
#  amt                         | 24.74
#  amount_clean                | 24.74
#  category                    | grocery_pos
#  cc_bic                      |
#  cc_num                      | 4642894980163
#  merch_eff_time              | 1325376383967287
#  merch_last_update_time      | 1325376383455
#  merch_lat                   | 40.275890999999994
#  merch_long                  | -96.011548
#  merch_zipcode               | 68348
#  merchant                    | fraud_Rutherford-...
#  merchant_name               | Rutherford-Mertz
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:06:23
#  trans_num                   | d71c95ab6b7356dd7...
#  trans_date_trans_time_utc8  | 2019-01-01 00:06:23
#  merch_eff_time_utc8         | 2012-01-01 08:06:23
#  merch_last_update_time_utc8 | 2012-01-01 08:06:23
#  person_name                 | Eddie|Mendez!!!
#  first                       | Eddie
#  last                        | Mendez
#  gender                      | M
#  street                      | 1831 Faith View S...
#  city                        | Clarinda
#  state                       | IA
#  zip                         | 51632
#  lat                         | 40.7491
#  long                        | -95.038
#  city_pop                    | 7297
#  job                         | IT trainer
#  birth_year                  | 1990
#  dob                         | 1990-07-13
# -RECORD 11------------------------------------------
#  Unnamed: 0                  | 11
#  amt                         | 7.77
#  amount_clean                | 7.77
#  category                    | shopping_net
#  cc_bic                      | DEUTUS33TRF
#  cc_num                      | 377234009633447
#  merch_eff_time              | 1325376413912233
#  merch_last_update_time      | 1325376413859
#  merch_lat                   | 40.103866
#  merch_long                  | -78.624459
#  merch_zipcode               | 15554
#  merchant                    | fraud_Kerluke-Abs...
#  merchant_name               | Kerluke-Abshire
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:06:53
#  trans_num                   | 3c74776e558f1499a...
#  trans_date_trans_time_utc8  | 2019-01-01 00:06:53
#  merch_eff_time_utc8         | 2012-01-01 08:06:53
#  merch_last_update_time_utc8 | 2012-01-01 08:06:53
#  person_name                 | Theresa@Blackwell
#  first                       | Theresa
#  last                        | Blackwell
#  gender                      | F
#  street                      | 43576 Kristina Is...
#  city                        | Shenandoah Junction
#  state                       | WV
#  zip                         | 25442
#  lat                         | 39.3716
#  long                        | -77.8229
#  city_pop                    | 1925
#  job                         | Systems developer
#  birth_year                  | 1966
#  dob                         | 1966-02-14
# -RECORD 12------------------------------------------
#  Unnamed: 0                  | 12
#  amt                         | 71.22
#  amount_clean                | 71.22
#  category                    | grocery_pos
#  cc_bic                      | DEUTUS33TRF
#  cc_num                      | 180042946491150
#  merch_eff_time              | 1325376416569264
#  merch_last_update_time      | 1325376416443
#  merch_lat                   | 27.630593
#  merch_long                  | -82.308891
#  merch_zipcode               | 33598
#  merchant                    | fraud_Lockman Ltd
#  merchant_name               | Lockman Ltd
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:06:56
#  trans_num                   | c1d9a7ddb1e34639f...
#  trans_date_trans_time_utc8  | 2019-01-01 00:06:56
#  merch_eff_time_utc8         | 2012-01-01 08:06:56
#  merch_last_update_time_utc8 | 2012-01-01 08:06:56
#  person_name                 | Charles|Robles!!!
#  first                       | Charles
#  last                        | Robles
#  gender                      | M
#  street                      | 3337 Lisa Divide
#  city                        | Saint Petersburg
#  state                       | FL
#  zip                         | 33710
#  lat                         | 27.7898
#  long                        | -82.7243
#  city_pop                    | 341043
#  job                         | Engineer, land
#  birth_year                  | 1989
#  dob                         | 1989-02-28
# -RECORD 13------------------------------------------
#  Unnamed: 0                  | 13
#  amt                         | 96.29
#  amount_clean                | 96.29
#  category                    | grocery_pos
#  cc_bic                      | ACEEUS31
#  cc_num                      | 5559857416065248
#  merch_eff_time              | 1325376447442465
#  merch_last_update_time      | 1325376447771
#  merch_lat                   | 41.65752
#  merch_long                  | -122.230347
#  merch_zipcode               | NULL
#  merchant                    | fraud_Kiehn Inc
#  merchant_name               | Kiehn Inc
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:07:27
#  trans_num                   | 413636e759663f264...
#  trans_date_trans_time_utc8  | 2019-01-01 00:07:27
#  merch_eff_time_utc8         | 2012-01-01 08:07:27
#  merch_last_update_time_utc8 | 2012-01-01 08:07:27
#  person_name                 | Jack@Hill
#  first                       | Jack
#  last                        | Hill
#  gender                      | M
#  street                      | 5916 Susan Bridge...
#  city                        | Grenada
#  state                       | CA
#  zip                         | 96038
#  lat                         | 41.6125
#  long                        | -122.5258
#  city_pop                    | 589
#  job                         | Systems analyst
#  birth_year                  | 1945
#  dob                         | 1945-12-21
# -RECORD 14------------------------------------------
#  Unnamed: 0                  | 14
#  amt                         | 7.77
#  amount_clean                | 7.77
#  category                    | shopping_pos
#  cc_bic                      | ACEEUS31
#  cc_num                      | 3514865930894695
#  merch_eff_time              | 132537654399153
#  merch_last_update_time      | 1325376543282
#  merch_lat                   | 32.863258
#  merch_long                  | -106.520205
#  merch_zipcode               | NULL
#  merchant                    | fraud_Beier-Hyatt
#  merchant_name               | Beier-Hyatt
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:09:03
#  trans_num                   | 8a6293af5ed278dea...
#  trans_date_trans_time_utc8  | 2019-01-01 00:09:03
#  merch_eff_time_utc8         | 1974-03-15 08:00:54
#  merch_last_update_time_utc8 | 2012-01-01 08:09:03
#  person_name                 | Christopher@Casta...
#  first                       | Christopher
#  last                        | Castaneda
#  gender                      | M
#  street                      | 1632 Cohen Drive ...
#  city                        | High Rolls Mounta...
#  state                       | NM
#  zip                         | 88325
#  lat                         | 32.9396
#  long                        | -105.8189
#  city_pop                    | 899
#  job                         | Naval architect
#  birth_year                  | 1967
#  dob                         | 1967-08-30
# -RECORD 15------------------------------------------
#  Unnamed: 0                  | 15
#  amt                         | 3.26
#  amount_clean                | 3.26
#  category                    | shopping_net
#  cc_bic                      | CITIUS33CHI
#  cc_num                      | 6011999606625827
#  merch_eff_time              | 1325376560448213
#  merch_last_update_time      | 1325376560435
#  merch_lat                   | 41.831174
#  merch_long                  | -74.335559
#  merch_zipcode               | 12446
#  merchant                    | fraud_Schmidt and...
#  merchant_name               | Schmidt and Sons
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:09:20
#  trans_num                   | baae0b096835c9758...
#  trans_date_trans_time_utc8  | 2019-01-01 00:09:20
#  merch_eff_time_utc8         | 2012-01-01 08:09:20
#  merch_last_update_time_utc8 | 2012-01-01 08:09:20
#  person_name                 | Ronald@Carson
#  first                       | Ronald
#  last                        | Carson
#  gender                      | M
#  street                      | 870 Rocha Drive
#  city                        | Harrington Park
#  state                       | NJ
#  zip                         | 7640
#  lat                         | 40.9918
#  long                        | -73.98
#  city_pop                    | 4664
#  job                         | Radiographer, dia...
#  birth_year                  | 1965
#  dob                         | 1965-06-30
# -RECORD 16------------------------------------------
#  Unnamed: 0                  | 16
#  amt                         | 327.0
#  amount_clean                | 327.00
#  category                    | misc_net
#  cc_bic                      | CITIUS33CHI
#  cc_num                      | 6011860238257910
#  merch_eff_time              | 132537664977977
#  merch_last_update_time      | 1325376649369
#  merch_lat                   | 36.384091999999995
#  merch_long                  | -99.048472
#  merch_zipcode               | 73852
#  merchant                    | fraud_Lebsack and...
#  merchant_name               | Lebsack and Sons
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:10:49
#  trans_num                   | 991c04803b4d4eeab...
#  trans_date_trans_time_utc8  | 2019-01-01 00:10:49
#  merch_eff_time_utc8         | 1974-03-15 08:01:04
#  merch_last_update_time_utc8 | 2012-01-01 08:10:49
#  person_name                 | Lisa, Mendez
#  first                       | Lisa
#  last                        |  Mendez
#  gender                      | F
#  street                      | 44259 Beth Statio...
#  city                        | Lahoma
#  state                       | OK
#  zip                         | 73754
#  lat                         | 36.385
#  long                        | -98.0727
#  city_pop                    | 1078
#  job                         | Programme researc...
#  birth_year                  | 1952
#  dob                         | 1952-07-06
# -RECORD 17------------------------------------------
#  Unnamed: 0                  | 17
#  amt                         | 341.67
#  amount_clean                | 341.67
#  category                    | shopping_pos
#  cc_bic                      |
#  cc_num                      | 3565423334076143
#  merch_eff_time              | 1325376658780653
#  merch_last_update_time      | 1325376658125
#  merch_lat                   | 38.674491
#  merch_long                  | -88.305767
#  merch_zipcode               | 62824
#  merchant                    | fraud_Mayert Group
#  merchant_name               | Mayert Group
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:10:58
#  trans_num                   | f12cf52be2175703d...
#  trans_date_trans_time_utc8  | 2019-01-01 00:10:58
#  merch_eff_time_utc8         | 2012-01-01 08:10:58
#  merch_last_update_time_utc8 | 2012-01-01 08:10:58
#  person_name                 | Nathan,Thomas,eeeee
#  first                       | Nathan
#  last                        | Thomas
#  gender                      | M
#  street                      | 4923 Campbell Pin...
#  city                        | Carlisle
#  state                       | IN
#  zip                         | 47838
#  lat                         | 38.9763
#  long                        | -87.3667
#  city_pop                    | 4081
#  job                         | Energy engineer
#  birth_year                  | 1938
#  dob                         | 1938-03-15
# -RECORD 18------------------------------------------
#  Unnamed: 0                  | 18
#  amt                         | 63.07
#  amount_clean                | 63.07
#  category                    | food_dining
#  cc_bic                      | APBCUS61
#  cc_num                      | 2348245054386329
#  merch_eff_time              | 1325376674645606
#  merch_last_update_time      | 1325376674800
#  merch_lat                   | 41.430274
#  merch_long                  | -79.492553
#  merch_zipcode               | 16364
#  merchant                    | fraud_Konopelski,...
#  merchant_name               | Konopelski, Schne...
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:11:14
#  trans_num                   | 8500f3d459047eac8...
#  trans_date_trans_time_utc8  | 2019-01-01 00:11:14
#  merch_eff_time_utc8         | 2012-01-01 08:11:14
#  merch_last_update_time_utc8 | 2012-01-01 08:11:14
#  person_name                 | Justin, Gay
#  first                       | Justin
#  last                        |  Gay
#  gender                      | M
#  street                      | 268 Hayes Rue Sui...
#  city                        | Harborcreek
#  state                       | PA
#  zip                         | 16421
#  lat                         | 42.1767
#  long                        | -79.9416
#  city_pop                    | 2518
#  job                         | Event organiser
#  birth_year                  | 1946
#  dob                         | 1946-02-02
# -RECORD 19------------------------------------------
#  Unnamed: 0                  | 19
#  amt                         | 44.71
#  amount_clean                | 44.71
#  category                    | grocery_pos
#  cc_bic                      |
#  cc_num                      | 4956828990005111019
#  merch_eff_time              | 132537675433224
#  merch_last_update_time      | 1325376754863
#  merch_lat                   | 40.079588
#  merch_long                  | -74.84808699999999
#  merch_zipcode               | 08016
#  merchant                    | fraud_Schultz, Si...
#  merchant_name               | Schultz, Simonis ...
#  fraud_flag                  | fraud_
#  derived_fraud_flag          | true
#  is_fraud_bool               | false
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:12:34
#  trans_num                   | 09eff9c806365e2a6...
#  trans_date_trans_time_utc8  | 2019-01-01 00:12:34
#  merch_eff_time_utc8         | 1974-03-15 08:01:15
#  merch_last_update_time_utc8 | 2012-01-01 08:12:34
#  person_name                 | Kenneth, , Robins...
#  first                       | Kenneth
#  last                        |
#  gender                      | M
#  street                      | 269 Sanchez Rapids
#  city                        | Elizabeth
#  state                       | NJ
#  zip                         | 7208
#  lat                         | 40.6747
#  long                        | -74.2239
#  city_pop                    | 124967
#  job                         | Operational resea...
#  birth_year                  | 1980
#  dob                         | 1980-12-21
# only showing top 20 rows

# %%
# Basic Stats
flattened_df.describe().show(vertical=True)
# Out:
# [Stage 14:====================================>                     (5 + 3) / 8]
# -RECORD 0-------------------------------------------
#  summary                     | count
#  Unnamed: 0                  | 1296675
#  amt                         | 1296675
#  amount_clean                | 1296675
#  category                    | 1296675
#  cc_bic                      | 1296675
#  cc_num                      | 1296675
#  merch_eff_time              | 1296675
#  merch_last_update_time      | 1296675
#  merch_lat                   | 1296675
#  merch_long                  | 1296675
#  merch_zipcode               | 1100702
#  merchant                    | 1296675
#  merchant_name               | 1296675
#  fraud_flag                  | 1296675
#  is_fraud                    | 1296675
#  trans_date_trans_time       | 1296675
#  trans_num                   | 1296675
#  merch_eff_time_utc8         | 1296675
#  merch_last_update_time_utc8 | 1296675
#  person_name                 | 1296675
#  first                       | 1296675
#  last                        | 1296675
#  gender                      | 1296675
#  street                      | 1296675
#  city                        | 1296675
#  state                       | 1296675
#  zip                         | 1296675
#  lat                         | 1296675
#  long                        | 1296675
#  city_pop                    | 1296675
#  job                         | 1296675
#  birth_year                  | 1296675
#  dob                         | 1296675
# -RECORD 1-------------------------------------------
#  summary                     | mean
#  Unnamed: 0                  | 648337.0
#  amt                         | 70.35103545607025
#  amount_clean                | 70.351035
#  category                    | NULL
#  cc_bic                      | NULL
#  cc_num                      | 4.171920420796760...
#  merch_eff_time              | 1.226971654789970...
#  merch_last_update_time      | 1.226790968939934...
#  merch_lat                   | 38.53733804469964
#  merch_long                  | -90.2264647989727
#  merch_zipcode               | 46825.75415053302
#  merchant                    | NULL
#  merchant_name               | NULL
#  fraud_flag                  | NULL
#  is_fraud                    | 0.005788651743883394
#  trans_date_trans_time       | NULL
#  trans_num                   | Infinity
#  merch_eff_time_utc8         | NULL
#  merch_last_update_time_utc8 | NULL
#  person_name                 | NULL
#  first                       | NULL
#  last                        | NULL
#  gender                      | NULL
#  street                      | NULL
#  city                        | NULL
#  state                       | NULL
#  zip                         | 48800.67109722945
#  lat                         | 38.537621614905994
#  long                        | -90.22633537865437
#  city_pop                    | 88824.44056297839
#  job                         | NULL
#  birth_year                  | 1973.2574546436076
#  dob                         | NULL
# -RECORD 2-------------------------------------------
#  summary                     | stddev
#  Unnamed: 0                  | 374317.9744882685
#  amt                         | 160.31603857152763
#  amount_clean                | 160.31603857152763
#  category                    | NULL
#  cc_bic                      | NULL
#  cc_num                      | 1.308806447000240...
#  merch_eff_time              | 3.678596149934447E14
#  merch_last_update_time      | 3.68057477577884E11
#  merch_lat                   | 5.109788369679179
#  merch_long                  | 13.771090564792415
#  merch_zipcode               | 25834.001159599786
#  merchant                    | NULL
#  merchant_name               | NULL
#  fraud_flag                  | NULL
#  is_fraud                    | 0.07586268973125175
#  trans_date_trans_time       | NULL
#  trans_num                   | NaN
#  merch_eff_time_utc8         | NULL
#  merch_last_update_time_utc8 | NULL
#  person_name                 | NULL
#  first                       | NULL
#  last                        | NULL
#  gender                      | NULL
#  street                      | NULL
#  city                        | NULL
#  state                       | NULL
#  zip                         | 26893.222476485957
#  lat                         | 5.075808438803922
#  long                        | 13.759076946486333
#  city_pop                    | 301956.360688751
#  job                         | NULL
#  birth_year                  | 17.378484767364515
#  dob                         | NULL
# -RECORD 3-------------------------------------------
#  summary                     | min
#  Unnamed: 0                  | 0
#  amt                         | 1.0
#  amount_clean                | 1.00
#  category                    | entertainment
#  cc_bic                      |
#  cc_num                      | 180011453250192
#  merch_eff_time              | 1325376018798532
#  merch_last_update_time      | 1325376018666
#  merch_lat                   | 19.027785
#  merch_long                  | -100.000064
#  merch_zipcode               | 01001
#  merchant                    | fraud_Abbott-Rogahn
#  merchant_name               | Abbott-Rogahn
#  fraud_flag                  | fraud_
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:00:18
#  trans_num                   | 00000ecad06b03d3a...
#  merch_eff_time_utc8         | 1970-01-01 11:41:29
#  merch_last_update_time_utc8 | 1970-06-03 17:37:24
#  person_name                 | Aaron, , Murray N...
#  first                       | Aaron
#  last                        |
#  gender                      | F
#  street                      | 000 Jennifer Mills
#  city                        | Achille
#  state                       | AK
#  zip                         | 10018
#  lat                         | 20.0271
#  long                        | -100.138
#  city_pop                    | 100
#  job                         | Academic librarian
#  birth_year                  | 1924
#  dob                         | 1924-10-30
# -RECORD 4-------------------------------------------
#  summary                     | max
#  Unnamed: 0                  | 999999
#  amt                         | 9999.39
#  amount_clean                | 28948.90
#  category                    | travel
#  cc_bic                      | Null
#  cc_num                      | 676372984911
#  merch_eff_time              | 1371816817420462
#  merch_last_update_time      | 1371816817611
#  merch_lat                   | 67.510267
#  merch_long                  | -99.999914
#  merch_zipcode               | 99403
#  merchant                    | fraud_Zulauf LLC
#  merchant_name               | Zulauf LLC
#  fraud_flag                  | fraud_
#  is_fraud                    | 1
#  trans_date_trans_time       | 2020-06-21 12:13:37
#  trans_num                   | ffffef9d89e7d02d8...
#  merch_eff_time_utc8         | 2013-06-21 20:13:37
#  merch_last_update_time_utc8 | 2013-06-21 20:13:37
#  person_name                 | Zachary|Boone!!!
#  first                       | Zachary
#  last                        | Zuniga
#  gender                      | M
#  street                      | 99736 Rose Shoals...
#  city                        | Zavalla
#  state                       | WY
#  zip                         | 99783
#  lat                         | 66.6933
#  long                        | -99.959
#  city_pop                    | 9993
#  job                         | Writer
#  birth_year                  | 2005
#  dob                         | 2005-01-29

# %% [markdown]
# #### From the basic statistics summary:
# 1. Count: merch_zipcode is the only column that does not have the same count number (if not necessary, we can drop this column)
# 2. min & max :
#     1. Column amt has min -> 1.0 and max ->9999.39 with mean-> 70.35 (possible normalization required for this column. Check the median amt)
#     2. Column year (birth) range between 1924 to 2005. (we can check the median year)

# %%
flattened_df.summary("count", "min", "max", "25%", "50%", "75%").show(vertical=True)
# Out:
# [Stage 19:>                                                         (0 + 1) / 1]
# -RECORD 0-------------------------------------------
#  summary                     | count
#  Unnamed: 0                  | 1296675
#  amt                         | 1296675
#  amount_clean                | 1296675
#  category                    | 1296675
#  cc_bic                      | 1296675
#  cc_num                      | 1296675
#  merch_eff_time              | 1296675
#  merch_last_update_time      | 1296675
#  merch_lat                   | 1296675
#  merch_long                  | 1296675
#  merch_zipcode               | 1100702
#  merchant                    | 1296675
#  merchant_name               | 1296675
#  fraud_flag                  | 1296675
#  is_fraud                    | 1296675
#  trans_date_trans_time       | 1296675
#  trans_num                   | 1296675
#  merch_eff_time_utc8         | 1296675
#  merch_last_update_time_utc8 | 1296675
#  person_name                 | 1296675
#  first                       | 1296675
#  last                        | 1296675
#  gender                      | 1296675
#  street                      | 1296675
#  city                        | 1296675
#  state                       | 1296675
#  zip                         | 1296675
#  lat                         | 1296675
#  long                        | 1296675
#  city_pop                    | 1296675
#  job                         | 1296675
#  birth_year                  | 1296675
#  dob                         | 1296675
# -RECORD 1-------------------------------------------
#  summary                     | min
#  Unnamed: 0                  | 0
#  amt                         | 1.0
#  amount_clean                | 1.00
#  category                    | entertainment
#  cc_bic                      |
#  cc_num                      | 180011453250192
#  merch_eff_time              | 1325376018798532
#  merch_last_update_time      | 1325376018666
#  merch_lat                   | 19.027785
#  merch_long                  | -100.000064
#  merch_zipcode               | 01001
#  merchant                    | fraud_Abbott-Rogahn
#  merchant_name               | Abbott-Rogahn
#  fraud_flag                  | fraud_
#  is_fraud                    | 0
#  trans_date_trans_time       | 2019-01-01 00:00:18
#  trans_num                   | 00000ecad06b03d3a...
#  merch_eff_time_utc8         | 1970-01-01 11:41:29
#  merch_last_update_time_utc8 | 1970-06-03 17:37:24
#  person_name                 | Aaron, , Murray N...
#  first                       | Aaron
#  last                        |
#  gender                      | F
#  street                      | 000 Jennifer Mills
#  city                        | Achille
#  state                       | AK
#  zip                         | 10018
#  lat                         | 20.0271
#  long                        | -100.138
#  city_pop                    | 100
#  job                         | Academic librarian
#  birth_year                  | 1924
#  dob                         | 1924-10-30
# -RECORD 2-------------------------------------------
#  summary                     | max
#  Unnamed: 0                  | 999999
#  amt                         | 9999.39
#  amount_clean                | 28948.90
#  category                    | travel
#  cc_bic                      | Null
#  cc_num                      | 676372984911
#  merch_eff_time              | 1371816817420462
#  merch_last_update_time      | 1371816817611
#  merch_lat                   | 67.510267
#  merch_long                  | -99.999914
#  merch_zipcode               | 99403
#  merchant                    | fraud_Zulauf LLC
#  merchant_name               | Zulauf LLC
#  fraud_flag                  | fraud_
#  is_fraud                    | 1
#  trans_date_trans_time       | 2020-06-21 12:13:37
#  trans_num                   | ffffef9d89e7d02d8...
#  merch_eff_time_utc8         | 2013-06-21 20:13:37
#  merch_last_update_time_utc8 | 2013-06-21 20:13:37
#  person_name                 | Zachary|Boone!!!
#  first                       | Zachary
#  last                        | Zuniga
#  gender                      | M
#  street                      | 99736 Rose Shoals...
#  city                        | Zavalla
#  state                       | WY
#  zip                         | 99783
#  lat                         | 66.6933
#  long                        | -99.959
#  city_pop                    | 9993
#  job                         | Writer
#  birth_year                  | 2005
#  dob                         | 2005-01-29
# -RECORD 3-------------------------------------------
#  summary                     | 25%
#  Unnamed: 0                  | 324147.0
#  amt                         | 9.65
#  amount_clean                | 9.65
#  category                    | NULL
#  cc_bic                      | NULL
#  cc_num                      | 1.8004294649115E14
#  merch_eff_time              | 1.334936463383901E15
#  merch_last_update_time      | 1.334930795173E12
#  merch_lat                   | 34.732637
#  merch_long                  | -96.897666
#  merch_zipcode               | 25114.0
#  merchant                    | NULL
#  merchant_name               | NULL
#  fraud_flag                  | NULL
#  is_fraud                    | 0.0
#  trans_date_trans_time       | NULL
#  trans_num                   | 7.183344251117977E31
#  merch_eff_time_utc8         | NULL
#  merch_last_update_time_utc8 | NULL
#  person_name                 | NULL
#  first                       | NULL
#  last                        | NULL
#  gender                      | NULL
#  street                      | NULL
#  city                        | NULL
#  state                       | NULL
#  zip                         | 26237.0
#  lat                         | 34.6689
#  long                        | -96.798
#  city_pop                    | 743.0
#  job                         | NULL
#  birth_year                  | 1962
#  dob                         | NULL
# -RECORD 4-------------------------------------------
#  summary                     | 50%
#  Unnamed: 0                  | 648286.0
#  amt                         | 47.52
#  amount_clean                | 47.52
#  category                    | NULL
#  cc_bic                      | NULL
#  cc_num                      | 3.521417320836166E15
#  merch_eff_time              | 1.346515770875741E15
#  merch_last_update_time      | 1.346513749814E12
#  merch_lat                   | 39.365573
#  merch_long                  | -87.438914
#  merch_zipcode               | 45860.0
#  merchant                    | NULL
#  merchant_name               | NULL
#  fraud_flag                  | NULL
#  is_fraud                    | 0.0
#  trans_date_trans_time       | NULL
#  trans_num                   | 7.183344251117977E31
#  merch_eff_time_utc8         | NULL
#  merch_last_update_time_utc8 | NULL
#  person_name                 | NULL
#  first                       | NULL
#  last                        | NULL
#  gender                      | NULL
#  street                      | NULL
#  city                        | NULL
#  state                       | NULL
#  zip                         | 48174.0
#  lat                         | 39.3543
#  long                        | -87.4769
#  city_pop                    | 2456.0
#  job                         | NULL
#  birth_year                  | 1975
#  dob                         | NULL
# -RECORD 5-------------------------------------------
#  summary                     | 75%
#  Unnamed: 0                  | 972559.0
#  amt                         | 83.13
#  amount_clean                | 83.13
#  category                    | NULL
#  cc_bic                      | NULL
#  cc_num                      | 4.642255475285942E15
#  merch_eff_time              | 1.357587763957084E15
#  merch_last_update_time      | 1.357570762286E12
#  merch_lat                   | 41.956503999999995
#  merch_long                  | -80.23738399999999
#  merch_zipcode               | 68316.0
#  merchant                    | NULL
#  merchant_name               | NULL
#  fraud_flag                  | NULL
#  is_fraud                    | 0.0
#  trans_date_trans_time       | NULL
#  trans_num                   | Infinity
#  merch_eff_time_utc8         | NULL
#  merch_last_update_time_utc8 | NULL
#  person_name                 | NULL
#  first                       | NULL
#  last                        | NULL
#  gender                      | NULL
#  street                      | NULL
#  city                        | NULL
#  state                       | NULL
#  zip                         | 72042.0
#  lat                         | 41.9404
#  long                        | -80.158
#  city_pop                    | 20328.0
#  job                         | NULL
#  birth_year                  | 1987
#  dob                         | NULL

# %% [markdown]
# #### From the interquartile statistics summary:
#
# 1. Column amt: We can see the Q1-Q3 is more close with each other contrary to the max value
# 2. (Birth) year range column: In the Q1-Q3, we can see that the values are 1962, 1975 and 1987. Which are all under 1990. There is a possible correlation between customer age and fraud cases.
#
# 3. merchant name column will be required to have separate fraud_flag column based on their name. Next, we can compare with the existing is_fraud column and how much are the count different or similar from each other.

# %%
from pyspark.sql.functions import countDistinct

# Get distinct counts for categorical column
for column in flattened_df.columns:
    flattened_df.select(countDistinct(col(column)).alias(f"distinct_{column}")).show()
# Out:
# +-------------------+
# |distinct_Unnamed: 0|
# +-------------------+
# |            1296675|
# +-------------------+
# +------------+
# |distinct_amt|
# +------------+
# |       52928|
# +------------+
# +-----------------+
# |distinct_category|
# +-----------------+
# |               14|
# +-----------------+
# +---------------+
# |distinct_cc_bic|
# +---------------+
# |              9|
# +---------------+
# +---------------+
# |distinct_cc_num|
# +---------------+
# |            983|
# +---------------+
# +-----------------+
# |distinct_is_fraud|
# +-----------------+
# |                2|
# +-----------------+
# +-----------------------+
# |distinct_merch_eff_time|
# +-----------------------+
# |                1296675|
# +-----------------------+
# +-------------------------------+
# |distinct_merch_last_update_time|
# +-------------------------------+
# |                        1296657|
# +-------------------------------+
# +------------------+
# |distinct_merch_lat|
# +------------------+
# |           1247805|
# +------------------+
# +-------------------+
# |distinct_merch_long|
# +-------------------+
# |            1275745|
# +-------------------+
# +----------------------+
# |distinct_merch_zipcode|
# +----------------------+
# |                 28336|
# +----------------------+
# +-----------------+
# |distinct_merchant|
# +-----------------+
# |              693|
# +-----------------+
# +------------------------------+
# |distinct_trans_date_trans_time|
# +------------------------------+
# |                       1274791|
# +------------------------------+
# +------------------+
# |distinct_trans_num|
# +------------------+
# |           1296675|
# +------------------+
# +-----------------------------------+
# |distinct_trans_date_trans_time_utc8|
# +-----------------------------------+
# |                            1274791|
# +-----------------------------------+
# +----------------------------+
# |distinct_merch_eff_time_utc8|
# +----------------------------+
# |                     1276958|
# +----------------------------+
# +------------------------------------+
# |distinct_merch_last_update_time_utc8|
# +------------------------------------+
# |                             1276942|
# +------------------------------------+
# +--------------------+
# |distinct_person_name|
# +--------------------+
# |                5759|
# +--------------------+
# +--------------+
# |distinct_first|
# +--------------+
# |           352|
# +--------------+
# +-------------+
# |distinct_last|
# +-------------+
# |          959|
# +-------------+
# +---------------+
# |distinct_gender|
# +---------------+
# |              2|
# +---------------+
# +---------------+
# |distinct_street|
# +---------------+
# |            983|
# +---------------+
# +-------------+
# |distinct_city|
# +-------------+
# |          894|
# +-------------+
# +--------------+
# |distinct_state|
# +--------------+
# |            51|
# +--------------+
# +------------+
# |distinct_zip|
# +------------+
# |         970|
# +------------+
# +------------+
# |distinct_lat|
# +------------+
# |         968|
# +------------+
# +-------------+
# |distinct_long|
# +-------------+
# |          969|
# +-------------+
# +-----------------+
# |distinct_city_pop|
# +-----------------+
# |              879|
# +-----------------+
# +------------+
# |distinct_job|
# +------------+
# |         494|
# +------------+
# [Stage 393:===================================>                     (5 + 3) / 8]
# +------------+
# |distinct_dob|
# +------------+
# |         968|
# +------------+

# %%
try:
    # Get distinct category for each categorical column
    selected_cols = ["category", "is_fraud", "merchant", 
                     "gender", "person_name", 
                     "city", 
                     "state", "job", 
                     "city_pop", "dob"]

    for column in selected_cols:
        flattened_df.select(column).distinct().show()

except Exception as e:
    print(f"Error {e}")
# Out:
# +--------------+
# |      category|
# +--------------+
# |        travel|
# |      misc_net|
# |   grocery_pos|
# |     kids_pets|
# |  shopping_net|
# |   grocery_net|
# |   food_dining|
# | gas_transport|
# | personal_care|
# |health_fitness|
# | entertainment|
# |          home|
# |      misc_pos|
# |  shopping_pos|
# +--------------+
# +--------+
# |is_fraud|
# +--------+
# |       0|
# |       1|
# +--------+
# +--------------------+
# |            merchant|
# +--------------------+
# |  fraud_Rau and Sons|
# |    fraud_Herman Inc|
# |     fraud_Thiel PLC|
# |fraud_O'Hara-Wild...|
# |fraud_Bradtke, To...|
# |fraud_Altenwerth,...|
# |fraud_Robel, Cumm...|
# | fraud_Greenholt Ltd|
# |fraud_Ledner, Har...|
# |  fraud_Waelchi-Wolf|
# |   fraud_Effertz LLC|
# |fraud_Smitham-Sch...|
# | fraud_Kihn-Schuster|
# |   fraud_Hills-Boyer|
# |fraud_Douglas, Du...|
# |      fraud_Jast Ltd|
# |fraud_Stroman, Hu...|
# |fraud_Kerluke-Abs...|
# |fraud_Gottlieb-Ha...|
# |fraud_Rippin-VonR...|
# +--------------------+
# only showing top 20 rows
# +------+
# |gender|
# +------+
# |     F|
# |     M|
# +------+
# +-----------------+
# |             city|
# +-----------------+
# |Kingsford Heights|
# |             Jelm|
# |            Tyler|
# |          Palermo|
# |      Springfield|
# |           Corona|
# |          Whigham|
# |          Tyaskin|
# |      Woods Cross|
# |           Auburn|
# |      New Memphis|
# |  North Las Vegas|
# |       Plainfield|
# |          Acworth|
# |          Phoenix|
# |            Rhame|
# |         Falconer|
# |       Georgetown|
# |         Doe Hill|
# |          Harwood|
# +-----------------+
# only showing top 20 rows
# +-----+
# |state|
# +-----+
# |   AZ|
# |   SC|
# |   LA|
# |   MN|
# |   NJ|
# |   DC|
# |   OR|
# |   VA|
# |   RI|
# |   WY|
# |   KY|
# |   NH|
# |   MI|
# |   NV|
# |   WI|
# |   ID|
# |   CA|
# |   NE|
# |   CT|
# |   MT|
# +-----+
# only showing top 20 rows
# +--------------------+
# |                 job|
# +--------------------+
# | Retail merchandiser|
# | Librarian, academic|
# |Designer, ceramic...|
# |Engineer, aeronau...|
# |    Catering manager|
# |English as a seco...|
# |Primary school te...|
# | Early years teacher|
# |Occupational hygi...|
# |Control and instr...|
# |   Transport planner|
# |Applications deve...|
# |       Art therapist|
# |  Petroleum engineer|
# |       Stage manager|
# |Investment banker...|
# |Conservator, furn...|
# |          Counsellor|
# |     Product manager|
# |Sports administrator|
# +--------------------+
# only showing top 20 rows
# [Stage 202:===================================>                     (5 + 3) / 8]
# +--------+
# |city_pop|
# +--------+
# |     467|
# |    1512|
# |    9993|
# |   15269|
# |    5657|
# |     800|
# |   27020|
# |  817312|
# |   95015|
# |   35299|
# |      51|
# |  841711|
# |     475|
# |    1897|
# |     307|
# |     718|
# |  233060|
# |  601723|
# |     205|
# |     581|
# +--------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col, sum

# Count nulls per column
null_counts = flattened_df.select(
    [sum(col(c).isNull().cast("int")).alias(c) for c in flattened_df.columns]
)

null_counts.show(vertical=True)
# Out:
# [Stage 205:===================================>                     (5 + 3) / 8]
# -RECORD 0-----------------------------
#  Unnamed: 0                  | 0
#  amt                         | 0
#  category                    | 0
#  cc_bic                      | 0
#  cc_num                      | 0
#  is_fraud                    | 0
#  merch_eff_time              | 0
#  merch_last_update_time      | 0
#  merch_lat                   | 0
#  merch_long                  | 0
#  merch_zipcode               | 195973
#  merchant                    | 0
#  trans_date_trans_time       | 0
#  trans_num                   | 0
#  trans_date_trans_time_utc8  | 0
#  merch_eff_time_utc8         | 0
#  merch_last_update_time_utc8 | 0
#  first                       | 0
#  last                        | 0
#  gender                      | 0
#  street                      | 0
#  city                        | 0
#  state                       | 0
#  zip                         | 0
#  lat                         | 0
#  long                        | 0
#  city_pop                    | 0
#  job                         | 0
#  dob                         | 0

# %%
#drop merch_zipcode column bcs of high null counts. other columns has zero null count

flattened_df = flattened_df.drop("merch_zipcode")

flattened_df.show(3, vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  Unnamed: 0                  | 0
#  amt                         | 4.97
#  category                    | misc_net
#  cc_bic                      | CITIUS33CHI
#  cc_num                      | 2703186189652095
#  is_fraud                    | 0
#  merch_eff_time              | 1325376018798532
#  merch_last_update_time      | 1325376018666
#  merch_lat                   | 36.011293
#  merch_long                  | -82.048315
#  merchant                    | fraud_Rippin, Kub...
#  trans_date_trans_time       | 2019-01-01 00:00:18
#  trans_num                   | 0b242abb623afc578...
#  trans_date_trans_time_utc8  | 2019-01-01 00:00:18
#  merch_eff_time_utc8         | 2012-01-01 08:00:18
#  merch_last_update_time_utc8 | 2012-01-01 08:00:18
#  first                       | Jennifer
#  last                        | Banks
#  gender                      | F
#  street                      | 561 Perry Cove
#  city                        | Moravian Falls
#  state                       | NC
#  zip                         | 28654
#  lat                         | 36.0788
#  long                        | -81.1781
#  city_pop                    | 3495
#  job                         | Psychologist, cou...
#  dob                         | 1988-03-09
# -RECORD 1-------------------------------------------
#  Unnamed: 0                  | 1
#  amt                         | 107.23
#  category                    | grocery_pos
#  cc_bic                      | ADMDUS41
#  cc_num                      | 630423337322
#  is_fraud                    | 0
#  merch_eff_time              | 1325376044867960
#  merch_last_update_time      | 132537604479
#  merch_lat                   | 49.159046999999994
#  merch_long                  | -118.186462
#  merchant                    | fraud_Heller, Gut...
#  trans_date_trans_time       | 2019-01-01 00:00:44
#  trans_num                   | 1f76529f857473494...
#  trans_date_trans_time_utc8  | 2019-01-01 00:00:44
#  merch_eff_time_utc8         | 2012-01-01 08:00:44
#  merch_last_update_time_utc8 | 1974-03-15 08:00:04
#  first                       | Stephanie
#  last                        | Gill
#  gender                      | F
#  street                      | 43039 Riley Green...
#  city                        | Orient
#  state                       | WA
#  zip                         | 99160
#  lat                         | 48.8878
#  long                        | -118.2105
#  city_pop                    | 149
#  job                         | Special education...
#  dob                         | 1978-06-21
# -RECORD 2-------------------------------------------
#  Unnamed: 0                  | 2
#  amt                         | 220.11
#  category                    | entertainment
#  cc_bic                      | Null
#  cc_num                      | 38859492057661
#  is_fraud                    | 0
#  merch_eff_time              | 1325376051506840
#  merch_last_update_time      | 1325376051286
#  merch_lat                   | 43.150704
#  merch_long                  | -112.154481
#  merchant                    | fraud_Lind-Buckridge
#  trans_date_trans_time       | 2019-01-01 00:00:51
#  trans_num                   | a1a22d70485983eac...
#  trans_date_trans_time_utc8  | 2019-01-01 00:00:51
#  merch_eff_time_utc8         | 2012-01-01 08:00:51
#  merch_last_update_time_utc8 | 2012-01-01 08:00:51
#  first                       | Edward
#  last                        | Sanchez
#  gender                      | M
#  street                      | 594 White Dale Su...
#  city                        | Malad City
#  state                       | ID
#  zip                         | 83252
#  lat                         | 42.1808
#  long                        | -112.262
#  city_pop                    | 4154
#  job                         | Nature conservati...
#  dob                         | 1962-01-19
# only showing top 3 rows
